# %% [markdown]
# <a href="https://colab.research.google.com/github/MoraliShah/-doudna/blob/main/Python%20task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("/content/src_anx.csv")

# %%
data1
# Out:
#                                         SITE_ID  GENDER_CODE  AGE_GROUP  \
# 0      0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          3
# 1      0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 2      0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 3      0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 4      0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            2          4
# ...                                         ...          ...        ...
# 21521  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 21522  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 21523  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
# 21524  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 21525  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
#
#        SITE_POSTCODE  CALENDAR_MONTH  CALENDAR_YEAR  ANX_flag
# ...

# %%
data2 = pd.read_csv("/content/src_dep.csv")

# %%
data2
# Out:
#                                        SITE_ID  GENDER_CODE  AGE_GROUP  \
# 0     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 1     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# 2     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            2          5
# 3     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# 4     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# ...                                        ...          ...        ...
# 8777  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
# 8778  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
# 8779  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 8780  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 8781  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
#
#       SITE_POSTCODE  CALENDAR_MONTH  CALENDAR_YEAR  DEP_flag
# ...

# %%
data_template = pd.read_csv("/content/SP5-SP2-MHD-Data-template.csv")

# %%
data_template

# %%
data1.head(5)
# Out:
#                                     SITE_ID  GENDER_CODE  AGE_GROUP  \
# 0  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          3
# 1  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 2  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 3  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 4  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            2          4
#
#    SITE_POSTCODE  CALENDAR_MONTH  CALENDAR_YEAR  ANX_flag
# 0           4020               6           2021         2
# 1           4020              12           2015         3
# 2           4020              11           2016         2
# 3           4020               1           2018         1
# 4           4020              11           2019         1

# %%
data2.head(5)
# Out:
#                                     SITE_ID  GENDER_CODE  AGE_GROUP  \
# 0  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          4
# 1  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# 2  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            2          5
# 3  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# 4  0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
#
#    SITE_POSTCODE  CALENDAR_MONTH  CALENDAR_YEAR  DEP_flag
# 0           4020               5           2021         1
# 1           4020               6           2020         1
# 2           4020              11           2020         1
# 3           4020               9           2020         1
# 4           4020               7           2021         4

# %%
a = data1.ANX_flag
a
# Out:
# 0        2
# 1        3
# 2        2
# 3        1
# 4        1
#         ..
# 21521    2
# 21522    2
# 21523    3
# 21524    1
# 21525    2
# Name: ANX_flag, Length: 21526, dtype: int64

# %%
b = data2.DEP_flag
b
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       4
#        ..
# 8777    2
# 8778    1
# 8779    2
# 8780    1
# 8781    2
# Name: DEP_flag, Length: 8782, dtype: int64

# %%
c = pd.DataFrame(a,b)
c
# Out:
#           ANX_flag
# DEP_flag
# 1                3
# 1                3
# 1                3
# 1                3
# 4                1
# ...            ...
# 2                2
# 1                3
# 2                2
# 1                3
# 2                2
#
# [8782 rows x 1 columns]

# %%
n = pd.merge(data1,data2, how = 'inner')

n
# Out:
#                                        SITE_ID  GENDER_CODE  AGE_GROUP  \
# 0     0036703ea7e959b9d8d3bd68ae0aadf602ec6c7e            1          5
# 1     003a821c741d82a6a948a871d8fb7b5093f64346            1          3
# 2     003a821c741d82a6a948a871d8fb7b5093f64346            2          3
# 3     003a821c741d82a6a948a871d8fb7b5093f64346            2          3
# 4     003a821c741d82a6a948a871d8fb7b5093f64346            1          3
# ...                                        ...          ...        ...
# 5558  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 5559  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
# 5560  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
# 5561  fff8286e8c951e26c20c693589f944b2dbeb7147            2          5
# 5562  fff8286e8c951e26c20c693589f944b2dbeb7147            1          5
#
#       SITE_POSTCODE  CALENDAR_MONTH  CALENDAR_YEAR  ANX_flag  DEP_flag
# ...

# %%
from google.colab import files
n.to_csv('example_file.csv')
files.download('example_file.csv')
